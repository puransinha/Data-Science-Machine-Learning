# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
values = np.random.randn(100) # array of normally distributed random numbers
s = pd.Series(values) # generate a pandas series
s.plot(kind='hist', title='Normally distributed random values') 
plt.show()

# %%
df = pd.DataFrame({'Std_Id': [1, 2, 1, 4, 3, 8, 2, 12, 4, 1],
'R_No': [12, 14, 11, 16, 18, 18, 22, 13, 21, 17],
'Grade': ['a', 'a', 'b', 'a', 'b', 'c', 'b', 'a', 'b', 'a']})
#df=np.dtype(int)

df.describe()
# Out:
#           Std_Id       R_No
# count  10.000000  10.000000
# mean    3.800000  16.200000
# std     3.583915   3.705851
# min     1.000000  11.000000
# 25%     1.250000  13.250000
# 50%     2.500000  16.500000
# 75%     4.000000  18.000000
# max    12.000000  22.000000

# %%
df['Grade'].describe()
# Out:
# count     10
# unique     3
# top        a
# freq       5
# Name: Grade, dtype: object

# %%
df.loc[0,'Grade']='a'
df
# Out:
#    Std_Id  R_No Grade
# 0       1    12     a
# 1       2    14     a
# 2       1    11     b
# 3       4    16     a
# 4       3    18     b
# 5       8    18     c
# 6       2    22     b
# 7      12    13     a
# 8       4    21     b
# 9       1    17     a

# %%
df.loc[0,'C']=5
df
# Out:
#    Std_Id  R_No Grade    C
# 0       1    12     a  5.0
# 1       2    14     a  NaN
# 2       1    11     b  NaN
# 3       4    16     a  NaN
# 4       3    18     b  NaN
# 5       8    18     c  NaN
# 6       2    22     b  NaN
# 7      12    13     a  NaN
# 8       4    21     b  NaN
# 9       1    17     a  NaN

# %%
df.loc[10,'Grade']=('a')
df
# Out:
#     Std_Id  R_No Grade    C
# 0      1.0  12.0     a  5.0
# 1      2.0  14.0     a  NaN
# 2      1.0  11.0     b  NaN
# 3      4.0  16.0     a  NaN
# 4      3.0  18.0     b  NaN
# 5      8.0  18.0     c  NaN
# 6      2.0  22.0     b  NaN
# 7     12.0  13.0     a  NaN
# 8      4.0  21.0     b  NaN
# 9      1.0  17.0     a  NaN
# 10     NaN   NaN     a  NaN

# %%
#df.loc[10,'R_No']=(33)
#df.sort_values='R_No'
#df
# Out:
#     Std_Id  R_No Grade    C
# 0      1.0  12.0     a  5.0
# 1      2.0  14.0     a  NaN
# 2      1.0  11.0     b  NaN
# 3      4.0  16.0     a  NaN
# 4      3.0  18.0     b  NaN
# 5      8.0  18.0     c  NaN
# 6      2.0  22.0     b  NaN
# 7     12.0  13.0     a  NaN
# 8      4.0  21.0     b  NaN
# 9      1.0  17.0     a  NaN
# 10     NaN  33.0     a  NaN

# %%
df['C']==5
df
# Out:
#    Std_Id  R_No Grade  C
# 0       1    12     a  5
# 1       2    14     a  5
# 2       1    11     b  5
# 3       4    16     a  5
# 4       3    18     b  5
# 5       8    18     c  5
# 6       2    22     b  5
# 7      12    13     a  5
# 8       4    21     b  5
# 9       1    17     a  5

# %%
flo = pd.DataFrame({'Colour':['Red', 'Blue', 'Red', 'Blue']})
flo
# Out:
#   Colour
# 0    Red
# 1   Blue
# 2    Red
# 3   Blue

# %%
flo.loc[[2,3]]
# Out:
#   Colour
# 2    Red
# 3   Blue

# %%
flo.loc[2,'Size']='Big'
flo
# Out:
#   Colour Size
# 0    Red  NaN
# 1   Blue  NaN
# 2    Red  Big
# 3   Blue  NaN

# %%
flo.loc[3,'Name']='Merigold'
flo
# Out:
#   Colour Size      Name
# 0    Red  NaN       NaN
# 1   Blue  NaN       NaN
# 2    Red  Big       NaN
# 3   Blue  NaN  Merigold

# %%
flo.loc[[2,3]]
# Out:
#   Colour Size      Name
# 2    Red  Big       NaN
# 3   Blue  NaN  Merigold

# %%
flo.loc[2,'Colour']='Yellow'
flo.loc[1,'Name']='Tulip'
flo
# Out:
#    Colour       Name   Size
# 0     Red       Rose  Small
# 1    Blue      Tulip  Small
# 2  Yellow  SunFlower  Small
# 3    Blue   Merigold  Small

# %%
flo['Size']='Small'
flo
# Out:
#   Colour   Size
# 0    Red  Small
# 1   Blue  Small
# 2    Red  Small
# 3   Blue  Small

# %%
x=pd.read_csv('C:\\Users\\Puran Prakash Sinha\\Desktop\\Data Science\\Student.csv')

x
# Out:
#      Name  Gender  Class Roll No    Status
# 0   Sunil    Male      6      A1  Eligible
# 1    Anil    Male      4      A2  Eligible
# 2   Mohit    Male      5      A3  Eligible
# 3   Rohit    Male      7      A4  Eligible
# 4  Sudeep    Male      5      A5  Eligible
# 5  Garima  Female      6      A6  Eligible
# 6  Mahima  Female      8      A7  Eligible

# %%
x.loc[4,'Status']='Not Eligible'
x
# Out:
#      Name  Gender  Class Roll No        Status
# 0   Sunil    Male      6      A1      Eligible
# 1    Anil    Male      4      A2      Eligible
# 2   Mohit    Male      5      A3      Eligible
# 3   Rohit    Male      7      A4      Eligible
# 4  Sudeep    Male      5      A5  Not Eligible
# 5  Garima  Female      6      A6      Eligible
# 6  Mahima  Female      8      A7      Eligible

# %%
x.loc[4,'Name']=''
x
# Out:
#      Name  Gender  Class Roll No        Status
# 0   Sunil    Male      6      A1      Eligible
# 1    Anil    Male      4      A2      Eligible
# 2   Mohit    Male      5      A3      Eligible
# 3   Rohit    Male      7      A4      Eligible
# 4            Male      5      A5  Not Eligible
# 5  Garima  Female      6      A6      Eligible
# 6  Mahima  Female      8      A7      Eligible

# %%
#x.loc[7]={'Name':'Aditi', 'Gender':'Female', 'Class':9,'Roll No':'A9','Status':'Eligible'}
x.loc[7]={'Name':'Aditi', 'Gender':'Female', 'Class':9, 'Roll No':'A9', 'Status':'Eligible'}
x
# Out:
#      Name  Gender  Class Roll No    Status
# 0   Sunil    Male      6      A1  Eligible
# 1    Anil    Male      4      A2  Eligible
# 2   Mohit    Male      5      A3  Eligible
# 3   Rohit    Male      7      A4  Eligible
# 4  Sudeep    Male      5      A5  Eligible
# 5  Garima  Female      6      A6  Eligible
# 6  Mahima  Female      8      A7  Eligible
# 7   Aditi  Female      9      A9  Eligible

# %%
x.head(8)
# Out:
#      Name  Gender  Class Roll No    Status
# 0   Sunil    Male      6      A1  Eligible
# 1    Anil    Male      4      A2  Eligible
# 2   Mohit    Male      5      A3  Eligible
# 3   Rohit    Male      7      A4  Eligible
# 4  Sudeep    Male      5      A5  Eligible
# 5  Garima  Female      6      A6  Eligible
# 6  Mahima  Female      8      A7  Eligible
# 7   Aditi  Female      9      A9  Eligible

# %%
x['Class']>5
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6     True
# Name: Class, dtype: bool
